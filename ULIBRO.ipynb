# %% [markdown]
# <a href="https://colab.research.google.com/github/SuzaDamaRoja/RepositorioPrueba/blob/master/ULIBRO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Quest ulibro

# %% [markdown]
# ##Fotos del evento

# %% [markdown]
# ![funcion-de-la-biela.jpg](data:image/jpeg;base64,...)
